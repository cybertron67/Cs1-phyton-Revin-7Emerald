# %% [markdown]
# <a href="https://colab.research.google.com/github/cybertron67/Cs1-phyton-Revin-7Emerald/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Num1 = int(input("Enter your first number!"))
Num2 = int(input("Enter your second number!"))
Num3 = int(input("Enter your third number!"))

if Num1 > Num2:
  print(Num1, "is the biggest number")
elif Num1 > Num3:
  print(Num1, "is the biggest number")
elif Num2 > Num1:
  print(Num2, "is the greatest number")
elif Num2 > Num3:
  print(Num2, "is the greatest number")
elif Num3 > Num1:
  print(Num3, "is the greatest number")
elif Num3 > Num2:
  print(Num3, "is the greatest number")
elif Num1 == Num2:
  print(Num1, "is the biggest number")
elif Num1 == Num3:
  print(Num1, "is the biggest number")
elif Num2 == Num1:
  print(Num2, "is the greatest number")
elif Num2 == Num3:
  print(Num2, "is the greatest number")
elif Num3 == Num1:
  print(Num3, "is the greatest number")
else:
  print("All of them is equal!")
# Out:
# Enter your first number!12345678910
# Enter your second number!12345678910
# Enter your third number!12345678910
# 12345678910 is the biggest number
