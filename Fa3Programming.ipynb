# %% [markdown]
# <a href="https://colab.research.google.com/github/cybertron67/Cs1-phyton-Revin-7Emerald/blob/fa3programming/Fa3Programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#fa3prog1

Name = input("Enter Your Name!")
Age = int(input("Enter Your Age!"))
Course = input("Enter Your Course!")

print("Name:",Name)
print("Age:",Age)
print("Course:",Course)
# Out:
# Enter Your Name!Revin
# Enter Your Age!12
# Enter Your Course!Com sci
# Name: Revin
# Age: 12
# Course: Com sci

# %%
#fa3prog2
Score = int(input("Enter Your Exam Score!"))

if Score > 100:
  print("That's not a valid input!")
elif Score <= 75:
  print("You Have Failed! Try Your Best Next Time!")
elif Score >= 75:
  print("You Have Passed! Congratulations!")
else:
  print("Invalid Input!")

# %%
#fa3prog3

Student_Name = input("Enter Your Name!")
Student_Score = int(input("Enter Your Score!"))

if Student_Score > 100:
  print("That's not a valid input!")
elif Student_Score >= 90:
  print("Your Grade is A Congratulations!", Student_Name)
elif Student_Score >=80:
  print("Your grade is B Congratulations!", Student_Name)
elif Student_Score >=70:
  print("Your grade is C its average but nice!", Student_Name)
elif Student_Score < 70:
  print("Your grade is F you have failed!Work harder next time!", Student_Name)
else:
  print("Invalid Input!")
# Out:
# Enter Your Name!fender
# Enter Your Score!1000
# That's not a valid input!
